# %%
import pymongo
import pandas as pd
conn = "mongodb://heroku_2rsv5d25:iktn3mgtq8k4qluqgmlhug6kp6@ds233228.mlab.com:33228/heroku_2rsv5d25"
client = pymongo.MongoClient(conn)
# Dependencies
import requests
db=client.heroku_2rsv5d25
db.veilofignorance.drop()
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-10-8b2f4df1dfc1> in <module>()
#       6 import requests
#       7 db=client.veilofignorancedb
# ----> 8 db.veilofignorance.drop()
#       9 from bs4 import BeautifulSoup
#      10 from urllib.request import urlopen
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\collection.py in drop(self, session)
#    1090             self.write_concern,
#    1091             self.read_concern)
# -> 1092         dbo.drop_collection(self.__name, session=session)
#    1093
#    1094     def _delete(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\database.py in drop_collection(self, name_or_collection, session)
#     752                 write_concern=self._write_concern_for(session),
#     753                 parse_write_concern_error=True,
# --> 754                 session=session)
#     755
#     756     def validate_collection(self, name_or_collection,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\database.py in _command(self, sock_info, command, slave_ok, value, check, allowable_errors, read_preference, codec_options, write_concern, parse_write_concern_error, session, **kwargs)
#     512                 parse_write_concern_error=parse_write_concern_error,
#     513                 session=s,
# --> 514                 client=self.__client)
#     515
#     516     def command(self, command, value=1, check=True,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events)
#     577                            compression_ctx=self.compression_context,
#     578                            use_op_msg=self.op_msg_enabled,
# --> 579                            unacknowledged=unacknowledged)
#     580         except OperationFailure:
#     581             raise
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged)
#     148                 helpers._check_command_response(
#     149                     response_doc, None, allowable_errors,
# --> 150                     parse_write_concern_error=parse_write_concern_error)
#     151     except Exception as exc:
#     152         if publish:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     153
#     154             msg = msg or "%s"
# --> 155             raise OperationFailure(msg % errmsg, code, response)
#     156
#     157
#
# OperationFailure: not authorized on veilofignorancedb to execute command { drop: "veilofignorance", lsid: { id: UUID("ac6c0de9-9f83-4ef6-9f54-ef8ac2f7cc89") }, $clusterTime: { clusterTime: Timestamp(1554776831, 1), signature: { hash: BinData(0, 24FB9A239E461C1A64F27CEE4BBDBFDA19C880A5), keyId: 6628771203735617537 } }, $db: "veilofignorancedb", $readPreference: { mode: "primary" } }

# %%
stateID = {'Arkansas':['05','AR'], 'California':['06','CA'], 'Illinois':['17','IL'], 'Kansas':['20','KS'], 'Mississippi':['28','MS'], 'Ohio':['39','OH'], 
           'Texas':['48','TX'], 'Alabama':['01','AL'], 'Iowa':['19','IA'], 'Louisiana':['22','LA'],'Minnesota':['27','MN'], 'Missouri':['9','MO'], 
           'Nebraska':['31','NE'], 'Arizona':['04','AZ'], 'Colorado':['08','CO'], 'Indiana':['18','IN'], 'Michigan':['26','MI'],
           'Montana':['30','MT'], 'New York':['36','NY'], 'Oregon':['41','OR'], 'Virginia':['51','VA'], 'Wyoming':['56','WY'],'North Carolina':['37','NC'], 
           'Oklahoma':['40','OK'], 'Tennessee':['47','TN'], 'Wisconsin':['55','WI'], 'Alaska':['02','AK'], 'Vermont':['50','VT'], 'North Dakota':['38','ND'],
           'Georgia':['13','GA'], 'Maine':['23','ME'], 'Rhode Island':['44','RI'], 'West Virginia':['54','WV'], 'Idaho':['16','ID'],'South Dakota':['46','SD'],
           'New Mexico':['35','NM'], 'Washington':['53','WA'], 'Pennsylvania':['42','PA'], 'Florida':['12','FL'], 'Utah':['49','UT'], 'Kentucky':['21','KY'],
           'New Hampshire':['33','NH'], 'South Carolina':['45','SC'], 'Nevada':['32','NV'], 'Hawaii':['15','HI'], 'New Jersey':['34','NJ'],'Connecticut':['09','CT']
           , 'Maryland':['24','MD'], 'Massachusetts':['25','MA'], 'Delaware':['10','DE'], 'District of Columbia':['11','DC'], 'United States':['100', 'US']}

# %%
def statescrape(state, stateID):

    source = 'https://www.census.gov/quickfacts/fact/table/' + str(state)+ '/PST045218'
    html = urlopen(source)
    soup = BeautifulSoup(html, 'html.parser')

    fulllist = []

    for i in soup.find_all('td'):
    
        fulllist.append(i.text)
     
    headinglist = []
    datalist = []

    for i in range(len(fulllist)):
        if i%2 == 0:
        
            x = fulllist[i].strip('\n')
            formatted = x.strip('\ue840\ue83f\n')
            headinglist.append(formatted)
        
        else:
        
            x = fulllist[i].strip('\n')
            formatted = x.strip('\ue840\ue83f\n') 
            datalist.append(formatted)    

    truedict = dict(zip(headinglist, datalist))  
    truedict['State'] = state
    truedict['StateID'] = stateID
    statedf = pd.DataFrame(truedict, index = [state])
    onestatedf = statedf
    
    return onestatedf

# %%
dflist = pd.DataFrame()
count = 0
for key, value in stateID.items():
    
    print(count, key, value)
    
    scraped_df = statescrape(value[1], value[0])
    
    dflist = dflist.append(scraped_df)
    count +=1
# Out:
# 0 Arkansas ['05', 'AR']
# 1 California ['06', 'CA']
# 2 Illinois ['17', 'IL']
# 3 Kansas ['20', 'KS']
# 4 Mississippi ['28', 'MS']
# 5 Ohio ['39', 'OH']
# 6 Texas ['48', 'TX']
# 7 Alabama ['01', 'AL']
# 8 Iowa ['19', 'IA']
# 9 Louisiana ['22', 'LA']
# 10 Minnesota ['27', 'MN']
# 11 Missouri ['9', 'MO']
# 12 Nebraska ['31', 'NE']
# 13 Arizona ['04', 'AZ']
# 14 Colorado ['08', 'CO']
# 15 Indiana ['18', 'IN']
# 16 Michigan ['26', 'MI']
# 17 Montana ['30', 'MT']
# 18 New York ['36', 'NY']
# 19 Oregon ['41', 'OR']
# 20 Virginia ['51', 'VA']
# 21 Wyoming ['56', 'WY']
# 22 North Carolina ['37', 'NC']
# 23 Oklahoma ['40', 'OK']
# 24 Tennessee ['47', 'TN']
# 25 Wisconsin ['55', 'WI']
# 26 Alaska ['02', 'AK']
# 27 Vermont ['50', 'VT']
# 28 North Dakota ['38', 'ND']
# 29 Georgia ['13', 'GA']
# 30 Maine ['23', 'ME']
# 31 Rhode Island ['44', 'RI']
# 32 West Virginia ['54', 'WV']
# 33 Idaho ['16', 'ID']
# 34 South Dakota ['46', 'SD']
# 35 New Mexico ['35', 'NM']
# 36 Washington ['53', 'WA']
# 37 Pennsylvania ['42', 'PA']
# 38 Florida ['12', 'FL']
# 39 Utah ['49', 'UT']
# 40 Kentucky ['21', 'KY']
# 41 New Hampshire ['33', 'NH']
# 42 South Carolina ['45', 'SC']
# 43 Nevada ['32', 'NV']
# 44 Hawaii ['15', 'HI']
# 45 New Jersey ['34', 'NJ']
# 46 Connecticut ['09', 'CT']
# 47 Maryland ['24', 'MD']
# 48 Massachusetts ['25', 'MA']
# 49 Delaware ['10', 'DE']
# 50 District of Columbia ['11', 'DC']
# 51 United States ['100', 'US']

# %%
dflist
# Out:
#    Population estimates, July 1, 2018,  (V2018)  \
# AR                                    3,013,825
# CA                                   39,557,045
# IL                                   12,741,080
# KS                                    2,911,505
# MS                                    2,986,530
# OH                                   11,689,442
# TX                                   28,701,845
# AL                                    4,887,871
# IA                                    3,156,145
# LA                                    4,659,978
# MN                                    5,611,179
# MO                                    6,126,452
# NE                                    1,929,268
# AZ                                    7,171,646
# CO                                    5,695,564
# IN                                    6,691,878
# MI                                    9,995,915
# MT                                    1,062,305
# NY                                   19,542,209
# OR                                    4,190,713
# VA                                    8,517,685
# WY                                      577,737
# NC                                   10,383,620
# OK                                    3,943,079
# TN                                    6,770,010
# WI                                    5,813,568
# AK                                      737,438
# VT                                      626,299
# ND                                      760,077
# GA                                   10,519,475
# ME                                    1,338,404
# RI                                    1,057,315
# WV                                    1,805,832
# ID                                    1,754,208
# SD                                      882,235
# NM                                    2,095,428
# WA                                    7,535,591
# PA                                   12,807,060
# FL                                   21,299,325
# UT                                    3,161,105
# KY                                    4,468,402
# NH                                    1,356,458
# SC                                    5,084,127
# NV                                    3,034,392
# HI                                    1,420,491
# NJ                                    8,908,520
# CT                                    3,572,665
# MD                                    6,042,718
# MA                                    6,902,149
# DE                                      967,171
# DC                                      702,455
# US                                  327,167,434
#
#    Population estimates, July 1, 2017,  (V2017)  \
# AR                                    3,004,279
# CA                                   39,536,653
# IL                                   12,802,023
# KS                                    2,913,123
# MS                                    2,984,100
# OH                                   11,658,609
# TX                                   28,304,596
# AL                                    4,874,747
# IA                                    3,145,711
# LA                                    4,684,333
# MN                                    5,576,606
# MO                                    6,113,532
# NE                                    1,920,076
# AZ                                    7,016,270
# CO                                    5,607,154
# IN                                    6,666,818
# MI                                    9,962,311
# MT                                    1,050,493
# NY                                   19,849,399
# OR                                    4,142,776
# VA                                    8,470,020
# WY                                      579,315
# NC                                   10,273,419
# OK                                    3,930,864
# TN                                    6,715,984
# WI                                    5,795,483
# AK                                      739,795
# VT                                      623,657
# ND                                      755,393
# GA                                   10,429,379
# ME                                    1,335,907
# RI                                    1,059,639
# WV                                    1,815,857
# ID                                    1,716,943
# SD                                      869,666
# NM                                    2,088,070
# WA                                    7,405,743
# PA                                   12,805,537
# FL                                   20,984,400
# UT                                    3,101,833
# KY                                    4,454,189
# NH                                    1,342,795
# SC                                    5,024,369
# NV                                    2,998,039
# HI                                    1,427,538
# NJ                                    9,005,644
# CT                                    3,588,184
# MD                                    6,052,177
# MA                                    6,859,819
# DE                                      961,939
# DC                                      693,972
# US                                  325,719,178
#
#    Population estimates base, April 1, 2010,  (V2018)  \
# AR                                          2,916,028
# CA                                         37,254,523
# IL                                         12,831,572
# KS                                          2,853,126
# MS                                          2,968,118
# OH                                         11,536,757
# TX                                         25,146,114
# AL                                          4,780,138
# IA                                          3,046,872
# LA                                          4,533,485
# MN                                          5,303,925
# MO                                          5,988,952
# NE                                          1,826,305
# AZ                                          6,392,288
# CO                                          5,029,316
# IN                                          6,484,061
# MI                                          9,884,117
# MT                                            989,409
# NY                                         19,378,124
# OR                                          3,831,075
# VA                                          8,001,055
# WY                                            563,773
# NC                                          9,535,736
# OK                                          3,751,583
# TN                                          6,346,286
# WI                                          5,687,282
# AK                                            710,249
# VT                                            625,744
# ND                                            672,576
# GA                                          9,688,709
# ME                                          1,328,369
# RI                                          1,052,957
# WV                                          1,853,001
# ID                                          1,567,657
# SD                                            814,198
# NM                                          2,059,180
# WA                                          6,724,540
# PA                                         12,702,873
# FL                                         18,804,580
# UT                                          2,763,891
# KY                                          4,339,333
# NH                                          1,316,464
# SC                                          4,625,381
# NV                                          2,700,679
# HI                                          1,360,307
# NJ                                          8,791,962
# CT                                          3,574,147
# MD                                          5,773,798
# MA                                          6,547,790
# DE                                            897,934
# DC                                            601,766
# US                                        308,758,105
#
#    Population estimates base, April 1, 2010,  (V2017)  \
# AR                                          2,916,031
# CA                                         37,254,518
# IL                                         12,831,565
# KS                                          2,853,130
# MS                                          2,968,103
# OH                                         11,536,730
# TX                                         25,146,100
# AL                                          4,780,135
# IA                                          3,046,869
# LA                                          4,533,478
# MN                                          5,303,924
# MO                                          5,988,925
# NE                                          1,826,327
# AZ                                          6,392,309
# CO                                          5,029,325
# IN                                          6,484,125
# MI                                          9,884,129
# MT                                            989,414
# NY                                         19,378,110
# OR                                          3,831,072
# VA                                          8,001,043
# WY                                            563,767
# NC                                          9,535,721
# OK                                          3,751,598
# TN                                          6,346,295
# WI                                          5,687,288
# AK                                            710,249
# VT                                            625,741
# ND                                            672,585
# GA                                          9,688,690
# ME                                          1,328,362
# RI                                          1,052,945
# WV                                          1,853,006
# ID                                          1,567,650
# SD                                            814,197
# NM                                          2,059,207
# WA                                          6,724,545
# PA                                         12,702,857
# FL                                         18,804,594
# UT                                          2,763,889
# KY                                          4,339,340
# NH                                          1,316,460
# SC                                          4,625,381
# NV                                          2,700,691
# HI                                          1,360,301
# NJ                                          8,791,953
# CT                                          3,574,114
# MD                                          5,773,807
# MA                                          6,547,808
# DE                                            897,936
# DC                                            601,766
# US                                        308,758,105
#
#    Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)  \
# AR                                               3.4%
# CA                                               6.2%
# IL                                              -0.7%
# KS                                               2.0%
# MS                                               0.6%
# OH                                               1.3%
# TX                                              14.1%
# AL                                               2.3%
# IA                                               3.6%
# LA                                               2.8%
# MN                                               5.8%
# MO                                               2.3%
# NE                                               5.6%
# AZ                                              12.2%
# CO                                              13.2%
# IN                                               3.2%
# MI                                               1.1%
# MT                                               7.4%
# NY                                               0.8%
# OR                                               9.4%
# VA                                               6.5%
# WY                                               2.5%
# NC                                               8.9%
# OK                                               5.1%
# TN                                               6.7%
# WI                                               2.2%
# AK                                               3.8%
# VT                                               0.1%
# ND                                              13.0%
# GA                                               8.6%
# ME                                               0.8%
# RI                                               0.4%
# WV                                              -2.5%
# ID                                              11.9%
# SD                                               8.4%
# NM                                               1.8%
# WA                                              12.1%
# PA                                               0.8%
# FL                                              13.3%
# UT                                              14.4%
# KY                                               3.0%
# NH                                               3.0%
# SC                                               9.9%
# NV                                              12.4%
# HI                                               4.4%
# NJ                                               1.3%
# CT                                                  Z
# MD                                               4.7%
# MA                                               5.4%
# DE                                               7.7%
# DC                                              16.7%
# US                                               6.0%
#
#    Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)  \
# AR                                               3.0%
# CA                                               6.1%
# IL                                              -0.2%
# KS                                               2.1%
# MS                                               0.5%
# OH                                               1.1%
# TX                                              12.6%
# AL                                               2.0%
# IA                                               3.2%
# LA                                               3.3%
# MN                                               5.1%
# MO                                               2.1%
# NE                                               5.1%
# AZ                                               9.8%
# CO                                              11.5%
# IN                                               2.8%
# MI                                               0.8%
# MT                                               6.2%
# NY                                               2.4%
# OR                                               8.1%
# VA                                               5.9%
# WY                                               2.8%
# NC                                               7.7%
# OK                                               4.8%
# TN                                               5.8%
# WI                                               1.9%
# AK                                               4.2%
# VT                                              -0.3%
# ND                                              12.3%
# GA                                               7.6%
# ME                                               0.6%
# RI                                               0.6%
# WV                                              -2.0%
# ID                                               9.5%
# SD                                               6.8%
# NM                                               1.4%
# WA                                              10.1%
# PA                                               0.8%
# FL                                              11.6%
# UT                                              12.2%
# KY                                               2.6%
# NH                                               2.0%
# SC                                               8.6%
# NV                                              11.0%
# HI                                               4.9%
# NJ                                               2.4%
# CT                                               0.4%
# MD                                               4.8%
# MA                                               4.8%
# DE                                               7.1%
# DC                                              15.3%
# US                                               5.5%
#
#    Population, Census, April 1, 2010 Persons under 5 years, percent  \
# AR                         2,915,918                           6.4%
# CA                        37,253,956                           6.3%
# IL                        12,830,632                           6.0%
# KS                         2,853,118                           6.6%
# MS                         2,967,297                           6.3%
# OH                        11,536,504                           6.0%
# TX                        25,145,561                           7.2%
# AL                         4,779,736                           6.0%
# IA                         3,046,355                           6.3%
# LA                         4,533,372                           6.7%
# MN                         5,303,925                           6.4%
# MO                         5,988,927                           6.1%
# NE                         1,826,341                           6.9%
# AZ                         6,392,017                           6.2%
# CO                         5,029,196                           6.0%
# IN                         6,483,802                           6.3%
# MI                         9,883,640                           5.8%
# MT                           989,415                           6.0%
# NY                        19,378,102                           5.9%
# OR                         3,831,074                           5.7%
# VA                         8,001,024                           6.0%
# WY                           563,626                           6.4%
# NC                         9,535,483                           5.9%
# OK                         3,751,351                           6.7%
# TN                         6,346,105                           6.1%
# WI                         5,686,986                           5.8%
# AK                           710,231                           7.3%
# VT                           625,741                           4.8%
# ND                           672,591                           7.2%
# GA                         9,687,653                           6.3%
# ME                         1,328,361                           4.8%
# RI                         1,052,567                           5.2%
# WV                         1,852,994                           5.4%
# ID                         1,567,582                           6.8%
# SD                           814,180                           7.1%
# NM                         2,059,179                           6.1%
# WA                         6,724,540                           6.2%
# PA                        12,702,379                           5.5%
# FL                        18,801,310                           5.4%
# UT                         2,763,885                           8.2%
# KY                         4,339,367                           6.2%
# NH                         1,316,470                           4.8%
# SC                         4,625,364                           5.8%
# NV                         2,700,551                           6.2%
# HI                         1,360,301                           6.3%
# NJ                         8,791,894                           5.8%
# CT                         3,574,097                           5.1%
# MD                         5,773,552                           6.1%
# MA                         6,547,629                           5.3%
# DE                           897,934                           5.7%
# DC                           601,723                           6.5%
# US                       308,745,538                           6.1%
#
#    Persons under 18 years, percent Persons 65 years and over, percent   ...    \
# AR                           23.5%                              16.6%   ...
# CA                           22.9%                              13.9%   ...
# IL                           22.6%                              15.2%   ...
# KS                           24.5%                              15.4%   ...
# MS                           23.9%                              15.5%   ...
# OH                           22.3%                              16.7%   ...
# TX                           26.0%                              12.3%   ...
# AL                           22.5%                              16.5%   ...
# IA                           23.3%                              16.7%   ...
# LA                           23.7%                              14.9%   ...
# MN                           23.3%                              15.4%   ...
# MO                           22.6%                              16.5%   ...
# NE                           24.8%                              15.4%   ...
# AZ                           23.3%                              17.1%   ...
# CO                           22.5%                              13.8%   ...
# IN                           23.6%                              15.4%   ...
# MI                           21.8%                              16.7%   ...
# MT                           21.8%                              18.1%   ...
# NY                           20.9%                              15.9%   ...
# OR                           21.1%                              17.1%   ...
# VA                           22.1%                              15.0%   ...
# WY                           23.6%                              15.8%   ...
# NC                           22.4%                              15.9%   ...
# OK                           24.4%                              15.3%   ...
# TN                           22.4%                              16.0%   ...
# WI                           22.1%                              16.5%   ...
# AK                           25.0%                              11.2%   ...
# VT                           18.7%                              18.7%   ...
# ND                           23.3%                              15.0%   ...
# GA                           24.1%                              13.5%   ...
# ME                           18.9%                              19.9%   ...
# RI                           19.6%                              16.8%   ...
# WV                           20.4%                              19.4%   ...
# ID                           25.8%                              15.4%   ...
# SD                           24.7%                              16.3%   ...
# NM                           23.4%                              16.9%   ...
# WA                           22.2%                              15.1%   ...
# PA                           20.8%                              17.8%   ...
# FL                           20.0%                              20.1%   ...
# UT                           29.9%                              10.8%   ...
# KY                           22.7%                              16.0%   ...
# NH                           19.3%                              17.6%   ...
# SC                           22.0%                              17.2%   ...
# NV                           22.9%                              15.3%   ...
# HI                           21.4%                              17.8%   ...
# NJ                           22.0%                              15.8%   ...
# CT                           20.7%                              16.8%   ...
# MD                           22.3%                              14.9%   ...
# MA                           20.0%                              16.2%   ...
# DE                           21.3%                              18.1%   ...
# DC                           17.9%                              12.1%   ...
# US                           22.6%                              15.6%   ...
#
#    Women-owned firms, 2012 Minority-owned firms, 2012  \
# AR                  75,962                     35,982
# CA               1,320,085                  1,619,857
# IL                 417,500                    311,684
# KS                  77,194                     26,127
# MS                  89,159                     74,824
# OH                 306,824                    122,653
# TX                 866,678                  1,070,392
# AL                 137,630                     92,219
# IA                  82,345                     14,707
# LA                 151,114                    126,100
# MN                 157,821                     47,302
# MO                 162,616                     61,035
# NE                  51,936                     14,571
# AZ                 182,425                    135,313
# CO                 194,508                     85,849
# IN                 162,798                     61,252
# MI                 306,986                    158,946
# MT                  35,449                      5,578
# NY                 725,709                    709,021
# OR                 123,015                     41,456
# VA                 236,290                    185,043
# WY                  19,344                      4,077
# NC                 287,058                    183,380
# OK                 105,168                     64,875
# TN                 195,694                    105,234
# WI                 133,859                     40,507
# AK                  22,141                     13,688
# VT                  23,417                      2,354
# ND                  20,316                      3,190
# GA                 376,506                    371,588
# ME                  42,067                      4,339
# RI                  30,484                     14,737
# WV                  39,065                      5,777
# ID                  45,121                     10,592
# SD                  23,722                      4,101
# NM                  59,044                     60,622
# WA                 187,677                     92,807
# PA                 304,803                    131,512
# FL                 807,817                    926,112
# UT                  76,269                     24,423
# KY                 106,011                     27,258
# NH                  38,525                      6,111
# SC                 131,856                     83,233
# NV                  82,508                     71,864
# HI                  44,453                     74,208
# NJ                 252,944                    237,242
# CT                 106,678                     56,113
# MD                 209,119                    203,394
# MA                 199,210                     89,967
# DE                  23,964                     14,440
# DC                  27,064                     29,983
# US               9,878,397                  7,952,386
#
#    Nonminority-owned firms, 2012 Veteran-owned firms, 2012  \
# AR                       189,029                    25,915
# CA                     1,819,107                   252,377
# IL                       795,129                    89,110
# KS                       204,562                    21,610
# MS                       155,094                    26,789
# OH                       759,569                    91,316
# TX                     1,224,845                   213,590
# AL                       272,651                    41,943
# IA                       236,561                    25,889
# LA                       277,676                    42,211
# MN                       428,716                    45,582
# MO                       415,972                    49,217
# NE                       144,122                    16,693
# AZ                       344,981                    46,780
# CO                       442,365                    51,722
# IN                       405,090                    45,174
# MI                       657,237                    71,861
# MT                       102,746                    11,486
# NY                     1,248,304                   137,532
# OR                       285,028                    30,918
# VA                       450,109                    76,434
# WY                        55,397                     6,470
# NC                       603,182                    86,571
# OK                       249,027                    36,273
# TN                       434,025                    59,379
# WI                       379,934                    39,830
# AK                        51,147                     7,953
# VT                        70,491                     8,237
# ND                        62,271                     6,584
# GA                       538,893                    96,787
# ME                       131,322                    15,689
# RI                        77,042                     9,904
# WV                       104,785                    12,912
# ID                       130,973                    12,804
# SD                        74,228                     8,604
# NM                        83,857                    14,096
# WA                       426,697                    49,331
# PA                       818,858                    97,969
# FL                     1,121,749                   185,756
# UT                       218,826                    18,754
# KY                       296,155                    33,208
# NH                       121,297                    16,119
# SC                       276,269                    47,987
# NV                       144,944                    23,049
# HI                        38,510                    11,148
# NJ                       533,808                    57,996
# CT                       259,614                    31,056
# MD                       314,902                    50,976
# MA                       499,959                    58,339
# DE                        54,782                     7,206
# DC                        29,521                     5,070
# US                    18,987,918                 2,521,682
#
#    Nonveteran-owned firms, 2012 Population per square mile, 2010  \
# AR                      192,988                             56.0
# CA                    3,176,341                            239.1
# IL                    1,006,885                            231.1
# KS                      203,401                             34.9
# MS                      198,566                             63.2
# OH                      776,193                            282.3
# TX                    2,057,218                             96.3
# AL                      316,984                             94.4
# IA                      217,779                             54.5
# LA                      354,460                            104.9
# MN                      419,628                             66.6
# MO                      415,542                             87.1
# NE                      137,254                             23.8
# AZ                      427,582                             56.3
# CO                      469,524                             48.5
# IN                      412,543                            181.0
# MI                      733,517                            174.8
# MT                       93,393                              6.8
# NY                    1,811,544                            411.2
# OR                      288,790                             39.9
# VA                      548,439                            202.6
# WY                       51,353                              5.8
# NC                      684,743                            196.1
# OK                      273,491                             54.7
# TN                      469,392                            153.9
# WI                      370,755                            105.0
# AK                       56,091                              1.2
# VT                       63,317                             67.9
# ND                       56,904                              9.7
# GA                      800,585                            168.4
# ME                      115,839                             43.1
# RI                       79,837                          1,018.1
# WV                       94,960                             77.1
# ID                      124,314                             19.0
# SD                       66,219                             10.7
# NM                      128,693                             17.0
# WA                      461,401                            101.2
# PA                      837,792                            283.9
# FL                    1,846,686                            350.6
# UT                      219,807                             33.6
# KY                      282,704                            109.9
# NH                      108,817                            147.0
# SC                      303,137                            153.9
# NV                      191,293                             24.6
# HI                      101,334                            211.8
# NJ                      707,975                          1,195.5
# CT                      281,182                            738.1
# MD                      462,232                            594.8
# MA                      525,667                            839.4
# DE                       60,318                            460.8
# DC                       54,217                          9,856.5
# US                   24,070,685                             87.4
#
#    Land area in square miles, 2010 FIPS Code State StateID
# AR                       52,035.48        05    AR      05
# CA                      155,779.22        06    CA      06
# IL                       55,518.93        17    IL      17
# KS                       81,758.72        20    KS      20
# MS                       46,923.27        28    MS      28
# OH                       40,860.69        39    OH      39
# TX                      261,231.71        48    TX      48
# AL                       50,645.33        01    AL      01
# IA                       55,857.13        19    IA      19
# LA                       43,203.90        22    LA      22
# MN                       79,626.74        27    MN      27
# MO                       68,741.52        29    MO       9
# NE                       76,824.17        31    NE      31
# AZ                      113,594.08        04    AZ      04
# CO                      103,641.89        08    CO      08
# IN                       35,826.11        18    IN      18
# MI                       56,538.90        26    MI      26
# MT                      145,545.80        30    MT      30
# NY                       47,126.40        36    NY      36
# OR                       95,988.01        41    OR      41
# VA                       39,490.09        51    VA      51
# WY                       97,093.14        56    WY      56
# NC                       48,617.91        37    NC      37
# OK                       68,594.92        40    OK      40
# TN                       41,234.90        47    TN      47
# WI                       54,157.80        55    WI      55
# AK                      570,640.95        02    AK      02
# VT                        9,216.66        50    VT      50
# ND                       69,000.80        38    ND      38
# GA                       57,513.49        13    GA      13
# ME                       30,842.92        23    ME      23
# RI                        1,033.81        44    RI      44
# WV                       24,038.21        54    WV      54
# ID                       82,643.12        16    ID      16
# SD                       75,811.00        46    SD      46
# NM                      121,298.15        35    NM      35
# WA                       66,455.52        53    WA      53
# PA                       44,742.70        42    PA      42
# FL                       53,624.76        12    FL      12
# UT                       82,169.62        49    UT      49
# KY                       39,486.34        21    KY      21
# NH                        8,952.65        33    NH      33
# SC                       30,060.70        45    SC      45
# NV                      109,781.18        32    NV      32
# HI                        6,422.63        15    HI      15
# NJ                        7,354.22        34    NJ      34
# CT                        4,842.36        09    CT      09
# MD                        9,707.24        24    MD      24
# MA                        7,800.06        25    MA      25
# DE                        1,948.54        10    DE      10
# DC                           61.05        11    DC      11
# US                    3,531,905.43        00    US     100
#
# [52 rows x 67 columns]

# %%
records = dflist.to_dict(orient = 'records')
records
# Out:
# [{'Population estimates, July 1, 2018,  (V2018)': '3,013,825',
#   'Population estimates, July 1, 2017,  (V2017)': '3,004,279',
#   'Population estimates base, April 1, 2010,  (V2018)': '2,916,028',
#   'Population estimates base, April 1, 2010,  (V2017)': '2,916,031',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '3.4%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '3.0%',
#   'Population, Census, April 1, 2010': '2,915,918',
#   'Persons under 5 years, percent': '6.4%',
#   'Persons under 18 years, percent': '23.5%',
#   'Persons 65 years and over, percent': '16.6%',
#   'Female persons, percent': '50.9%',
#   'White alone, percent': '79.3%',
#   'Black or African American alone, percent(a)': '15.7%',
#   'American Indian and Alaska Native alone, percent(a)': '1.0%',
#   'Asian alone, percent(a)': '1.6%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.3%',
#   'Two or More Races, percent': '2.1%',
#   'Hispanic or Latino, percent(b)': '7.6%',
#   'White alone, not Hispanic or Latino, percent': '72.5%',
#   'Veterans, 2013-2017': '206,796',
#   'Foreign born persons, percent, 2013-2017': '4.7%',
#   'Housing units,  July 1, 2017,  (V2017)': '1,370,111',
#   'Owner-occupied housing unit rate, 2013-2017': '65.6%',
#   'Median value of owner-occupied housing units, 2013-2017': '$118,500',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,039',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$336',
#   'Median gross rent, 2013-2017': '$709',
#   'Building permits, 2017': '10,795',
#   'Households, 2013-2017': '1,147,291',
#   'Persons per household, 2013-2017': '2.52',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '84.2%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '7.2%',
#   'Households with a computer, percent, 2013-2017': '81.9%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '66.7%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '85.6%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '22.0%',
#   'With a disability, under age 65 years, percent, 2013-2017': '12.5%',
#   'Persons  without health insurance, under age 65 years, percent': '9.3%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '57.9%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '53.1%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '4,307,264',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '15,792,628',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '62,712,925',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '31,256,110',
#   'Total retail sales, 2012 ($1,000)(c)': '36,815,256',
#   'Total retail sales per capita, 2012(c)': '$12,483',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '21.6',
#   'Median household income (in 2017 dollars), 2013-2017': '$43,813',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$24,426',
#   'Persons in poverty, percent': '16.4%',
#   'Total employer establishments, 2016': '65,6111',
#   'Total employment, 2016': '1,023,8541',
#   'Total annual payroll, 2016 ($1,000)': '40,969,0511',
#   'Total employment, percent change, 2015-2016': '2.1%1',
#   'Total nonemployer establishments, 2016': '201,227',
#   'All firms, 2012': '231,959',
#   'Men-owned firms, 2012': '123,158',
#   'Women-owned firms, 2012': '75,962',
#   'Minority-owned firms, 2012': '35,982',
#   'Nonminority-owned firms, 2012': '189,029',
#   'Veteran-owned firms, 2012': '25,915',
#   'Nonveteran-owned firms, 2012': '192,988',
#   'Population per square mile, 2010': '56.0',
#   'Land area in square miles, 2010': '52,035.48',
#   'FIPS Code': '05',
#   'State': 'AR',
#   'StateID': '05'},
#  {'Population estimates, July 1, 2018,  (V2018)': '39,557,045',
#   'Population estimates, July 1, 2017,  (V2017)': '39,536,653',
#   'Population estimates base, April 1, 2010,  (V2018)': '37,254,523',
#   'Population estimates base, April 1, 2010,  (V2017)': '37,254,518',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '6.2%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '6.1%',
#   'Population, Census, April 1, 2010': '37,253,956',
#   'Persons under 5 years, percent': '6.3%',
#   'Persons under 18 years, percent': '22.9%',
#   'Persons 65 years and over, percent': '13.9%',
#   'Female persons, percent': '50.3%',
#   'White alone, percent': '72.4%',
#   'Black or African American alone, percent(a)': '6.5%',
#   'American Indian and Alaska Native alone, percent(a)': '1.6%',
#   'Asian alone, percent(a)': '15.2%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.5%',
#   'Two or More Races, percent': '3.9%',
#   'Hispanic or Latino, percent(b)': '39.1%',
#   'White alone, not Hispanic or Latino, percent': '37.2%',
#   'Veterans, 2013-2017': '1,661,433',
#   'Foreign born persons, percent, 2013-2017': '27.0%',
#   'Housing units,  July 1, 2017,  (V2017)': '14,176,670',
#   'Owner-occupied housing unit rate, 2013-2017': '54.5%',
#   'Median value of owner-occupied housing units, 2013-2017': '$443,400',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$2,206',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$542',
#   'Median gross rent, 2013-2017': '$1,358',
#   'Building permits, 2017': '114,780',
#   'Households, 2013-2017': '12,888,128',
#   'Persons per household, 2013-2017': '2.96',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '86.2%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '44.0%',
#   'Households with a computer, percent, 2013-2017': '90.2%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '82.6%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '82.5%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '32.6%',
#   'With a disability, under age 65 years, percent, 2013-2017': '6.9%',
#   'Persons  without health insurance, under age 65 years, percent': '8.1%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '63.0%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '57.1%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '90,830,372',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '248,953,592',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '512,303,164',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '666,652,186',
#   'Total retail sales, 2012 ($1,000)(c)': '481,800,461',
#   'Total retail sales per capita, 2012(c)': '$12,665',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '28.8',
#   'Median household income (in 2017 dollars), 2013-2017': '$67,169',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$33,128',
#   'Persons in poverty, percent': '13.3%',
#   'Total employer establishments, 2016': '922,4771',
#   'Total employment, 2016': '14,600,3491',
#   'Total annual payroll, 2016 ($1,000)': '886,643,9231',
#   'Total employment, percent change, 2015-2016': '1.9%1',
#   'Total nonemployer establishments, 2016': '3,277,415',
#   'All firms, 2012': '3,548,449',
#   'Men-owned firms, 2012': '1,852,580',
#   'Women-owned firms, 2012': '1,320,085',
#   'Minority-owned firms, 2012': '1,619,857',
#   'Nonminority-owned firms, 2012': '1,819,107',
#   'Veteran-owned firms, 2012': '252,377',
#   'Nonveteran-owned firms, 2012': '3,176,341',
#   'Population per square mile, 2010': '239.1',
#   'Land area in square miles, 2010': '155,779.22',
#   'FIPS Code': '06',
#   'State': 'CA',
#   'StateID': '06'},
#  {'Population estimates, July 1, 2018,  (V2018)': '12,741,080',
#   'Population estimates, July 1, 2017,  (V2017)': '12,802,023',
#   'Population estimates base, April 1, 2010,  (V2018)': '12,831,572',
#   'Population estimates base, April 1, 2010,  (V2017)': '12,831,565',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '-0.7%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '-0.2%',
#   'Population, Census, April 1, 2010': '12,830,632',
#   'Persons under 5 years, percent': '6.0%',
#   'Persons under 18 years, percent': '22.6%',
#   'Persons 65 years and over, percent': '15.2%',
#   'Female persons, percent': '50.8%',
#   'White alone, percent': '77.1%',
#   'Black or African American alone, percent(a)': '14.6%',
#   'American Indian and Alaska Native alone, percent(a)': '0.6%',
#   'Asian alone, percent(a)': '5.7%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.0%',
#   'Hispanic or Latino, percent(b)': '17.3%',
#   'White alone, not Hispanic or Latino, percent': '61.3%',
#   'Veterans, 2013-2017': '614,725',
#   'Foreign born persons, percent, 2013-2017': '14.0%',
#   'Housing units,  July 1, 2017,  (V2017)': '5,359,557',
#   'Owner-occupied housing unit rate, 2013-2017': '66.1%',
#   'Median value of owner-occupied housing units, 2013-2017': '$179,700',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,633',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$603',
#   'Median gross rent, 2013-2017': '$952',
#   'Building permits, 2017': '24,992',
#   'Households, 2013-2017': '4,818,452',
#   'Persons per household, 2013-2017': '2.61',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '86.9%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '22.8%',
#   'Households with a computer, percent, 2013-2017': '86.7%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '78.4%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '88.6%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '33.4%',
#   'With a disability, under age 65 years, percent, 2013-2017': '7.1%',
#   'Persons  without health insurance, under age 65 years, percent': '7.8%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '65.2%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '60.4%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '27,937,381',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '83,431,778',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '281,037,755',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '295,456,992',
#   'Total retail sales, 2012 ($1,000)(c)': '166,634,514',
#   'Total retail sales per capita, 2012(c)': '$12,942',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '28.7',
#   'Median household income (in 2017 dollars), 2013-2017': '$61,229',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$32,924',
#   'Persons in poverty, percent': '12.6%',
#   'Total employer establishments, 2016': '319,6051',
#   'Total employment, 2016': '5,513,0711',
#   'Total annual payroll, 2016 ($1,000)': '295,308,4701',
#   'Total employment, percent change, 2015-2016': '1.6%1',
#   'Total nonemployer establishments, 2016': '981,735',
#   'All firms, 2012': '1,135,017',
#   'Men-owned firms, 2012': '609,648',
#   'Women-owned firms, 2012': '417,500',
#   'Minority-owned firms, 2012': '311,684',
#   'Nonminority-owned firms, 2012': '795,129',
#   'Veteran-owned firms, 2012': '89,110',
#   'Nonveteran-owned firms, 2012': '1,006,885',
#   'Population per square mile, 2010': '231.1',
#   'Land area in square miles, 2010': '55,518.93',
#   'FIPS Code': '17',
#   'State': 'IL',
#   'StateID': '17'},
#  {'Population estimates, July 1, 2018,  (V2018)': '2,911,505',
#   'Population estimates, July 1, 2017,  (V2017)': '2,913,123',
#   'Population estimates base, April 1, 2010,  (V2018)': '2,853,126',
#   'Population estimates base, April 1, 2010,  (V2017)': '2,853,130',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '2.0%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '2.1%',
#   'Population, Census, April 1, 2010': '2,853,118',
#   'Persons under 5 years, percent': '6.6%',
#   'Persons under 18 years, percent': '24.5%',
#   'Persons 65 years and over, percent': '15.4%',
#   'Female persons, percent': '50.2%',
#   'White alone, percent': '86.5%',
#   'Black or African American alone, percent(a)': '6.2%',
#   'American Indian and Alaska Native alone, percent(a)': '1.2%',
#   'Asian alone, percent(a)': '3.1%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '3.0%',
#   'Hispanic or Latino, percent(b)': '11.9%',
#   'White alone, not Hispanic or Latino, percent': '75.9%',
#   'Veterans, 2013-2017': '185,292',
#   'Foreign born persons, percent, 2013-2017': '7.0%',
#   'Housing units,  July 1, 2017,  (V2017)': '1,273,742',
#   'Owner-occupied housing unit rate, 2013-2017': '66.4%',
#   'Median value of owner-occupied housing units, 2013-2017': '$139,200',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,310',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$476',
#   'Median gross rent, 2013-2017': '$801',
#   'Building permits, 2017': '8,984',
#   'Households, 2013-2017': '1,121,943',
#   'Persons per household, 2013-2017': '2.52',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '83.7%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '11.5%',
#   'Households with a computer, percent, 2013-2017': '86.9%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '77.5%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '90.5%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '32.3%',
#   'With a disability, under age 65 years, percent, 2013-2017': '8.8%',
#   'Persons  without health insurance, under age 65 years, percent': '10.2%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '65.8%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '61.2%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '4,873,411',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '18,248,370',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '86,076,260',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '60,226,324',
#   'Total retail sales, 2012 ($1,000)(c)': '38,276,461',
#   'Total retail sales per capita, 2012(c)': '$13,263',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '19.2',
#   'Median household income (in 2017 dollars), 2013-2017': '$55,477',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$29,600',
#   'Persons in poverty, percent': '11.9%',
#   'Total employer establishments, 2016': '74,8841',
#   'Total employment, 2016': '1,184,7101',
#   'Total annual payroll, 2016 ($1,000)': '51,016,3181',
#   'Total employment, percent change, 2015-2016': '-0.4%1',
#   'Total nonemployer establishments, 2016': '198,254',
#   'All firms, 2012': '239,118',
#   'Men-owned firms, 2012': '125,169',
#   'Women-owned firms, 2012': '77,194',
#   'Minority-owned firms, 2012': '26,127',
#   'Nonminority-owned firms, 2012': '204,562',
#   'Veteran-owned firms, 2012': '21,610',
#   'Nonveteran-owned firms, 2012': '203,401',
#   'Population per square mile, 2010': '34.9',
#   'Land area in square miles, 2010': '81,758.72',
#   'FIPS Code': '20',
#   'State': 'KS',
#   'StateID': '20'},
#  {'Population estimates, July 1, 2018,  (V2018)': '2,986,530',
#   'Population estimates, July 1, 2017,  (V2017)': '2,984,100',
#   'Population estimates base, April 1, 2010,  (V2018)': '2,968,118',
#   'Population estimates base, April 1, 2010,  (V2017)': '2,968,103',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '0.6%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '0.5%',
#   'Population, Census, April 1, 2010': '2,967,297',
#   'Persons under 5 years, percent': '6.3%',
#   'Persons under 18 years, percent': '23.9%',
#   'Persons 65 years and over, percent': '15.5%',
#   'Female persons, percent': '51.5%',
#   'White alone, percent': '59.2%',
#   'Black or African American alone, percent(a)': '37.8%',
#   'American Indian and Alaska Native alone, percent(a)': '0.6%',
#   'Asian alone, percent(a)': '1.1%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '1.3%',
#   'Hispanic or Latino, percent(b)': '3.2%',
#   'White alone, not Hispanic or Latino, percent': '56.7%',
#   'Veterans, 2013-2017': '172,587',
#   'Foreign born persons, percent, 2013-2017': '2.3%',
#   'Housing units,  July 1, 2017,  (V2017)': '1,323,663',
#   'Owner-occupied housing unit rate, 2013-2017': '68.1%',
#   'Median value of owner-occupied housing units, 2013-2017': '$109,300',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,105',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$346',
#   'Median gross rent, 2013-2017': '$740',
#   'Building permits, 2017': '7,481',
#   'Households, 2013-2017': '1,103,514',
#   'Persons per household, 2013-2017': '2.62',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '86.3%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '3.9%',
#   'Households with a computer, percent, 2013-2017': '79.0%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '64.3%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '83.4%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '21.3%',
#   'With a disability, under age 65 years, percent, 2013-2017': '11.7%',
#   'Persons  without health insurance, under age 65 years, percent': '14.2%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '57.2%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '53.6%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '6,999,175',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '16,630,587',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '66,441,608',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '28,302,952',
#   'Total retail sales, 2012 ($1,000)(c)': '37,053,190',
#   'Total retail sales per capita, 2012(c)': '$12,413',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '24.4',
#   'Median household income (in 2017 dollars), 2013-2017': '$42,009',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$22,500',
#   'Persons in poverty, percent': '19.8%',
#   'Total employer establishments, 2016': '58,8501',
#   'Total employment, 2016': '939,3221',
#   'Total annual payroll, 2016 ($1,000)': '34,356,9611',
#   'Total employment, percent change, 2015-2016': '1.4%1',
#   'Total nonemployer establishments, 2016': '214,804',
#   'All firms, 2012': '235,454',
#   'Men-owned firms, 2012': '125,079',
#   'Women-owned firms, 2012': '89,159',
#   'Minority-owned firms, 2012': '74,824',
#   'Nonminority-owned firms, 2012': '155,094',
#   'Veteran-owned firms, 2012': '26,789',
#   'Nonveteran-owned firms, 2012': '198,566',
#   'Population per square mile, 2010': '63.2',
#   'Land area in square miles, 2010': '46,923.27',
#   'FIPS Code': '28',
#   'State': 'MS',
#   'StateID': '28'},
#  {'Population estimates, July 1, 2018,  (V2018)': '11,689,442',
#   'Population estimates, July 1, 2017,  (V2017)': '11,658,609',
#   'Population estimates base, April 1, 2010,  (V2018)': '11,536,757',
#   'Population estimates base, April 1, 2010,  (V2017)': '11,536,730',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '1.3%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '1.1%',
#   'Population, Census, April 1, 2010': '11,536,504',
#   'Persons under 5 years, percent': '6.0%',
#   'Persons under 18 years, percent': '22.3%',
#   'Persons 65 years and over, percent': '16.7%',
#   'Female persons, percent': '51.0%',
#   'White alone, percent': '82.2%',
#   'Black or African American alone, percent(a)': '12.9%',
#   'American Indian and Alaska Native alone, percent(a)': '0.3%',
#   'Asian alone, percent(a)': '2.3%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.3%',
#   'Hispanic or Latino, percent(b)': '3.8%',
#   'White alone, not Hispanic or Latino, percent': '79.1%',
#   'Veterans, 2013-2017': '752,153',
#   'Foreign born persons, percent, 2013-2017': '4.3%',
#   'Housing units,  July 1, 2017,  (V2017)': '5,201,485',
#   'Owner-occupied housing unit rate, 2013-2017': '66.1%',
#   'Median value of owner-occupied housing units, 2013-2017': '$135,100',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,247',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$458',
#   'Median gross rent, 2013-2017': '$764',
#   'Building permits, 2017': '23,917',
#   'Households, 2013-2017': '4,633,145',
#   'Persons per household, 2013-2017': '2.44',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '85.1%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '6.9%',
#   'Households with a computer, percent, 2013-2017': '85.8%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '77.1%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '89.8%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '27.2%',
#   'With a disability, under age 65 years, percent, 2013-2017': '10.0%',
#   'Persons  without health insurance, under age 65 years, percent': '7.0%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '63.1%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '58.9%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '20,652,777',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '80,915,693',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '313,629,976',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '155,426,023',
#   'Total retail sales, 2012 ($1,000)(c)': '153,553,997',
#   'Total retail sales per capita, 2012(c)': '$13,301',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '23.4',
#   'Median household income (in 2017 dollars), 2013-2017': '$52,407',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$29,011',
#   'Persons in poverty, percent': '14.0%',
#   'Total employer establishments, 2016': '252,2011',
#   'Total employment, 2016': '4,790,1781',
#   'Total annual payroll, 2016 ($1,000)': '218,466,7441',
#   'Total employment, percent change, 2015-2016': '1.5%1',
#   'Total nonemployer establishments, 2016': '768,858',
#   'All firms, 2012': '904,814',
#   'Men-owned firms, 2012': '510,078',
#   'Women-owned firms, 2012': '306,824',
#   'Minority-owned firms, 2012': '122,653',
#   'Nonminority-owned firms, 2012': '759,569',
#   'Veteran-owned firms, 2012': '91,316',
#   'Nonveteran-owned firms, 2012': '776,193',
#   'Population per square mile, 2010': '282.3',
#   'Land area in square miles, 2010': '40,860.69',
#   'FIPS Code': '39',
#   'State': 'OH',
#   'StateID': '39'},
#  {'Population estimates, July 1, 2018,  (V2018)': '28,701,845',
#   'Population estimates, July 1, 2017,  (V2017)': '28,304,596',
#   'Population estimates base, April 1, 2010,  (V2018)': '25,146,114',
#   'Population estimates base, April 1, 2010,  (V2017)': '25,146,100',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '14.1%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '12.6%',
#   'Population, Census, April 1, 2010': '25,145,561',
#   'Persons under 5 years, percent': '7.2%',
#   'Persons under 18 years, percent': '26.0%',
#   'Persons 65 years and over, percent': '12.3%',
#   'Female persons, percent': '50.3%',
#   'White alone, percent': '79.2%',
#   'Black or African American alone, percent(a)': '12.7%',
#   'American Indian and Alaska Native alone, percent(a)': '1.0%',
#   'Asian alone, percent(a)': '5.0%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.0%',
#   'Hispanic or Latino, percent(b)': '39.4%',
#   'White alone, not Hispanic or Latino, percent': '42.0%',
#   'Veterans, 2013-2017': '1,482,871',
#   'Foreign born persons, percent, 2013-2017': '16.9%',
#   'Housing units,  July 1, 2017,  (V2017)': '10,932,870',
#   'Owner-occupied housing unit rate, 2013-2017': '62.0%',
#   'Median value of owner-occupied housing units, 2013-2017': '$151,500',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,484',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$481',
#   'Median gross rent, 2013-2017': '$952',
#   'Building permits, 2017': '175,112',
#   'Households, 2013-2017': '9,430,419',
#   'Persons per household, 2013-2017': '2.84',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '83.8%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '35.3%',
#   'Households with a computer, percent, 2013-2017': '87.6%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '76.8%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '82.8%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '28.7%',
#   'With a disability, under age 65 years, percent, 2013-2017': '8.0%',
#   'Persons  without health insurance, under age 65 years, percent': '19.4%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '64.2%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '57.7%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '54,480,811',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '145,035,130',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '702,603,073',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '691,242,607',
#   'Total retail sales, 2012 ($1,000)(c)': '356,116,376',
#   'Total retail sales per capita, 2012(c)': '$13,666',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '26.1',
#   'Median household income (in 2017 dollars), 2013-2017': '$57,051',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$28,985',
#   'Persons in poverty, percent': '14.7%',
#   'Total employer establishments, 2016': '579,1681',
#   'Total employment, 2016': '10,429,9241',
#   'Total annual payroll, 2016 ($1,000)': '526,782,6431',
#   'Total employment, percent change, 2015-2016': '1.9%1',
#   'Total nonemployer establishments, 2016': '2,251,787',
#   'All firms, 2012': '2,356,748',
#   'Men-owned firms, 2012': '1,251,696',
#   'Women-owned firms, 2012': '866,678',
#   'Minority-owned firms, 2012': '1,070,392',
#   'Nonminority-owned firms, 2012': '1,224,845',
#   'Veteran-owned firms, 2012': '213,590',
#   'Nonveteran-owned firms, 2012': '2,057,218',
#   'Population per square mile, 2010': '96.3',
#   'Land area in square miles, 2010': '261,231.71',
#   'FIPS Code': '48',
#   'State': 'TX',
#   'StateID': '48'},
#  {'Population estimates, July 1, 2018,  (V2018)': '4,887,871',
#   'Population estimates, July 1, 2017,  (V2017)': '4,874,747',
#   'Population estimates base, April 1, 2010,  (V2018)': '4,780,138',
#   'Population estimates base, April 1, 2010,  (V2017)': '4,780,135',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '2.3%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '2.0%',
#   'Population, Census, April 1, 2010': '4,779,736',
#   'Persons under 5 years, percent': '6.0%',
#   'Persons under 18 years, percent': '22.5%',
#   'Persons 65 years and over, percent': '16.5%',
#   'Female persons, percent': '51.6%',
#   'White alone, percent': '69.2%',
#   'Black or African American alone, percent(a)': '26.8%',
#   'American Indian and Alaska Native alone, percent(a)': '0.7%',
#   'Asian alone, percent(a)': '1.5%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '1.7%',
#   'Hispanic or Latino, percent(b)': '4.3%',
#   'White alone, not Hispanic or Latino, percent': '65.6%',
#   'Veterans, 2013-2017': '341,642',
#   'Foreign born persons, percent, 2013-2017': '3.5%',
#   'Housing units,  July 1, 2017,  (V2017)': '2,258,596',
#   'Owner-occupied housing unit rate, 2013-2017': '68.6%',
#   'Median value of owner-occupied housing units, 2013-2017': '$132,100',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,149',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$348',
#   'Median gross rent, 2013-2017': '$747',
#   'Building permits, 2017': '14,799',
#   'Households, 2013-2017': '1,856,695',
#   'Persons per household, 2013-2017': '2.55',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '85.8%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '5.1%',
#   'Households with a computer, percent, 2013-2017': '81.4%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '70.2%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '85.3%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '24.5%',
#   'With a disability, under age 65 years, percent, 2013-2017': '11.7%',
#   'Persons  without health insurance, under age 65 years, percent': '11.1%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '57.3%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '52.4%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '7,576,462',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '26,039,632',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '124,809,759',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '57,746,565',
#   'Total retail sales, 2012 ($1,000)(c)': '58,564,965',
#   'Total retail sales per capita, 2012(c)': '$12,145',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '24.6',
#   'Median household income (in 2017 dollars), 2013-2017': '$46,472',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$25,746',
#   'Persons in poverty, percent': '16.9%',
#   'Total employer establishments, 2016': '99,5841',
#   'Total employment, 2016': '1,673,2491',
#   'Total annual payroll, 2016 ($1,000)': '68,970,6231',
#   'Total employment, percent change, 2015-2016': '2.4%1',
#   'Total nonemployer establishments, 2016': '324,994',
#   'All firms, 2012': '374,153',
#   'Men-owned firms, 2012': '203,604',
#   'Women-owned firms, 2012': '137,630',
#   'Minority-owned firms, 2012': '92,219',
#   'Nonminority-owned firms, 2012': '272,651',
#   'Veteran-owned firms, 2012': '41,943',
#   'Nonveteran-owned firms, 2012': '316,984',
#   'Population per square mile, 2010': '94.4',
#   'Land area in square miles, 2010': '50,645.33',
#   'FIPS Code': '01',
#   'State': 'AL',
#   'StateID': '01'},
#  {'Population estimates, July 1, 2018,  (V2018)': '3,156,145',
#   'Population estimates, July 1, 2017,  (V2017)': '3,145,711',
#   'Population estimates base, April 1, 2010,  (V2018)': '3,046,872',
#   'Population estimates base, April 1, 2010,  (V2017)': '3,046,869',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '3.6%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '3.2%',
#   'Population, Census, April 1, 2010': '3,046,355',
#   'Persons under 5 years, percent': '6.3%',
#   'Persons under 18 years, percent': '23.3%',
#   'Persons 65 years and over, percent': '16.7%',
#   'Female persons, percent': '50.3%',
#   'White alone, percent': '91.1%',
#   'Black or African American alone, percent(a)': '3.8%',
#   'American Indian and Alaska Native alone, percent(a)': '0.5%',
#   'Asian alone, percent(a)': '2.6%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '1.9%',
#   'Hispanic or Latino, percent(b)': '6.0%',
#   'White alone, not Hispanic or Latino, percent': '85.7%',
#   'Veterans, 2013-2017': '193,451',
#   'Foreign born persons, percent, 2013-2017': '5.0%',
#   'Housing units,  July 1, 2017,  (V2017)': '1,398,016',
#   'Owner-occupied housing unit rate, 2013-2017': '71.1%',
#   'Median value of owner-occupied housing units, 2013-2017': '$137,200',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,202',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$456',
#   'Median gross rent, 2013-2017': '$740',
#   'Building permits, 2017': '13,948',
#   'Households, 2013-2017': '1,251,587',
#   'Persons per household, 2013-2017': '2.41',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '84.7%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '7.6%',
#   'Households with a computer, percent, 2013-2017': '86.2%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '76.6%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '91.8%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '27.7%',
#   'With a disability, under age 65 years, percent, 2013-2017': '7.9%',
#   'Persons  without health insurance, under age 65 years, percent': '5.5%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '67.5%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '63.2%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '5,468,687',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '18,583,828',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '116,668,830',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '62,318,301',
#   'Total retail sales, 2012 ($1,000)(c)': '44,905,624',
#   'Total retail sales per capita, 2012(c)': '$14,607',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '19.0',
#   'Median household income (in 2017 dollars), 2013-2017': '$56,570',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$30,063',
#   'Persons in poverty, percent': '10.7%',
#   'Total employer establishments, 2016': '81,5631',
#   'Total employment, 2016': '1,354,4871',
#   'Total annual payroll, 2016 ($1,000)': '56,930,4351',
#   'Total employment, percent change, 2015-2016': '1.2%1',
#   'Total nonemployer establishments, 2016': '209,794',
#   'All firms, 2012': '259,121',
#   'Men-owned firms, 2012': '135,382',
#   'Women-owned firms, 2012': '82,345',
#   'Minority-owned firms, 2012': '14,707',
#   'Nonminority-owned firms, 2012': '236,561',
#   'Veteran-owned firms, 2012': '25,889',
#   'Nonveteran-owned firms, 2012': '217,779',
#   'Population per square mile, 2010': '54.5',
#   'Land area in square miles, 2010': '55,857.13',
#   'FIPS Code': '19',
#   'State': 'IA',
#   'StateID': '19'},
#  {'Population estimates, July 1, 2018,  (V2018)': '4,659,978',
#   'Population estimates, July 1, 2017,  (V2017)': '4,684,333',
#   'Population estimates base, April 1, 2010,  (V2018)': '4,533,485',
#   'Population estimates base, April 1, 2010,  (V2017)': '4,533,478',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '2.8%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '3.3%',
#   'Population, Census, April 1, 2010': '4,533,372',
#   'Persons under 5 years, percent': '6.7%',
#   'Persons under 18 years, percent': '23.7%',
#   'Persons 65 years and over, percent': '14.9%',
#   'Female persons, percent': '51.1%',
#   'White alone, percent': '63.0%',
#   'Black or African American alone, percent(a)': '32.6%',
#   'American Indian and Alaska Native alone, percent(a)': '0.8%',
#   'Asian alone, percent(a)': '1.9%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '1.7%',
#   'Hispanic or Latino, percent(b)': '5.2%',
#   'White alone, not Hispanic or Latino, percent': '58.7%',
#   'Veterans, 2013-2017': '254,920',
#   'Foreign born persons, percent, 2013-2017': '4.2%',
#   'Housing units,  July 1, 2017,  (V2017)': '2,061,420',
#   'Owner-occupied housing unit rate, 2013-2017': '65.5%',
#   'Median value of owner-occupied housing units, 2013-2017': '$152,900',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,234',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$326',
#   'Median gross rent, 2013-2017': '$825',
#   'Building permits, 2017': '15,224',
#   'Households, 2013-2017': '1,737,645',
#   'Persons per household, 2013-2017': '2.61',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '86.7%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '8.3%',
#   'Households with a computer, percent, 2013-2017': '81.6%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '70.2%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '84.3%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '23.4%',
#   'With a disability, under age 65 years, percent, 2013-2017': '10.9%',
#   'Persons  without health insurance, under age 65 years, percent': '9.7%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '59.6%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '55.5%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '11,697,949',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '27,951,792',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '271,191,050',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '68,012,838',
#   'Total retail sales, 2012 ($1,000)(c)': '61,396,364',
#   'Total retail sales per capita, 2012(c)': '$13,342',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '25.2',
#   'Median household income (in 2017 dollars), 2013-2017': '$46,710',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$26,205',
#   'Persons in poverty, percent': '19.7%',
#   'Total employer establishments, 2016': '105,7321',
#   'Total employment, 2016': '1,709,2261',
#   'Total annual payroll, 2016 ($1,000)': '75,125,4471',
#   'Total employment, percent change, 2015-2016': '-0.9%1',
#   'Total nonemployer establishments, 2016': '368,735',
#   'All firms, 2012': '414,291',
#   'Men-owned firms, 2012': '215,111',
#   'Women-owned firms, 2012': '151,114',
#   'Minority-owned firms, 2012': '126,100',
#   'Nonminority-owned firms, 2012': '277,676',
#   'Veteran-owned firms, 2012': '42,211',
#   'Nonveteran-owned firms, 2012': '354,460',
#   'Population per square mile, 2010': '104.9',
#   'Land area in square miles, 2010': '43,203.90',
#   'FIPS Code': '22',
#   'State': 'LA',
#   'StateID': '22'},
#  {'Population estimates, July 1, 2018,  (V2018)': '5,611,179',
#   'Population estimates, July 1, 2017,  (V2017)': '5,576,606',
#   'Population estimates base, April 1, 2010,  (V2018)': '5,303,925',
#   'Population estimates base, April 1, 2010,  (V2017)': '5,303,924',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '5.8%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '5.1%',
#   'Population, Census, April 1, 2010': '5,303,925',
#   'Persons under 5 years, percent': '6.4%',
#   'Persons under 18 years, percent': '23.3%',
#   'Persons 65 years and over, percent': '15.4%',
#   'Female persons, percent': '50.2%',
#   'White alone, percent': '84.4%',
#   'Black or African American alone, percent(a)': '6.5%',
#   'American Indian and Alaska Native alone, percent(a)': '1.4%',
#   'Asian alone, percent(a)': '5.1%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.5%',
#   'Hispanic or Latino, percent(b)': '5.4%',
#   'White alone, not Hispanic or Latino, percent': '79.9%',
#   'Veterans, 2013-2017': '319,438',
#   'Foreign born persons, percent, 2013-2017': '8.2%',
#   'Housing units,  July 1, 2017,  (V2017)': '2,437,711',
#   'Owner-occupied housing unit rate, 2013-2017': '71.6%',
#   'Median value of owner-occupied housing units, 2013-2017': '$199,700',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,506',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$499',
#   'Median gross rent, 2013-2017': '$906',
#   'Building permits, 2017': '21,953',
#   'Households, 2013-2017': '2,153,202',
#   'Persons per household, 2013-2017': '2.49',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '85.6%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '11.3%',
#   'Households with a computer, percent, 2013-2017': '89.1%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '80.8%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '92.8%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '34.8%',
#   'With a disability, under age 65 years, percent, 2013-2017': '7.3%',
#   'Persons  without health insurance, under age 65 years, percent': '5.1%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '69.8%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '66.1%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '11,722,627',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '40,403,572',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '123,076,309',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '104,485,117',
#   'Total retail sales, 2012 ($1,000)(c)': '78,898,182',
#   'Total retail sales per capita, 2012(c)': '$14,667',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '23.4',
#   'Median household income (in 2017 dollars), 2013-2017': '$65,699',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$34,712',
#   'Persons in poverty, percent': '9.5%',
#   'Total employer establishments, 2016': '150,1151',
#   'Total employment, 2016': '2,661,6271',
#   'Total annual payroll, 2016 ($1,000)': '137,135,9361',
#   'Total employment, percent change, 2015-2016': '1.9%1',
#   'Total nonemployer establishments, 2016': '403,926',
#   'All firms, 2012': '489,494',
#   'Men-owned firms, 2012': '268,710',
#   'Women-owned firms, 2012': '157,821',
#   'Minority-owned firms, 2012': '47,302',
#   'Nonminority-owned firms, 2012': '428,716',
#   'Veteran-owned firms, 2012': '45,582',
#   'Nonveteran-owned firms, 2012': '419,628',
#   'Population per square mile, 2010': '66.6',
#   'Land area in square miles, 2010': '79,626.74',
#   'FIPS Code': '27',
#   'State': 'MN',
#   'StateID': '27'},
#  {'Population estimates, July 1, 2018,  (V2018)': '6,126,452',
#   'Population estimates, July 1, 2017,  (V2017)': '6,113,532',
#   'Population estimates base, April 1, 2010,  (V2018)': '5,988,952',
#   'Population estimates base, April 1, 2010,  (V2017)': '5,988,925',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '2.3%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '2.1%',
#   'Population, Census, April 1, 2010': '5,988,927',
#   'Persons under 5 years, percent': '6.1%',
#   'Persons under 18 years, percent': '22.6%',
#   'Persons 65 years and over, percent': '16.5%',
#   'Female persons, percent': '50.9%',
#   'White alone, percent': '83.1%',
#   'Black or African American alone, percent(a)': '11.8%',
#   'American Indian and Alaska Native alone, percent(a)': '0.6%',
#   'Asian alone, percent(a)': '2.1%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.3%',
#   'Hispanic or Latino, percent(b)': '4.2%',
#   'White alone, not Hispanic or Latino, percent': '79.5%',
#   'Veterans, 2013-2017': '424,605',
#   'Foreign born persons, percent, 2013-2017': '4.0%',
#   'Housing units,  July 1, 2017,  (V2017)': '2,792,506',
#   'Owner-occupied housing unit rate, 2013-2017': '66.9%',
#   'Median value of owner-occupied housing units, 2013-2017': '$145,400',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,225',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$420',
#   'Median gross rent, 2013-2017': '$784',
#   'Building permits, 2017': '18,811',
#   'Households, 2013-2017': '2,386,203',
#   'Persons per household, 2013-2017': '2.47',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '84.3%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '6.0%',
#   'Households with a computer, percent, 2013-2017': '85.6%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '75.0%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '89.2%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '28.2%',
#   'With a disability, under age 65 years, percent, 2013-2017': '10.5%',
#   'Persons  without health insurance, under age 65 years, percent': '10.8%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '62.8%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '58.9%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '12,430,310',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '40,089,316',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '111,535,362',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '91,916,351',
#   'Total retail sales, 2012 ($1,000)(c)': '90,546,581',
#   'Total retail sales per capita, 2012(c)': '$15,036',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '23.5',
#   'Median household income (in 2017 dollars), 2013-2017': '$51,542',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$28,282',
#   'Persons in poverty, percent': '13.4%',
#   'Total employer establishments, 2016': '160,9121',
#   'Total employment, 2016': '2,494,7201',
#   'Total annual payroll, 2016 ($1,000)': '112,072,1151',
#   'Total employment, percent change, 2015-2016': '2.1%1',
#   'Total nonemployer establishments, 2016': '409,303',
#   'All firms, 2012': '491,606',
#   'Men-owned firms, 2012': '257,948',
#   'Women-owned firms, 2012': '162,616',
#   'Minority-owned firms, 2012': '61,035',
#   'Nonminority-owned firms, 2012': '415,972',
#   'Veteran-owned firms, 2012': '49,217',
#   'Nonveteran-owned firms, 2012': '415,542',
#   'Population per square mile, 2010': '87.1',
#   'Land area in square miles, 2010': '68,741.52',
#   'FIPS Code': '29',
#   'State': 'MO',
#   'StateID': '9'},
#  {'Population estimates, July 1, 2018,  (V2018)': '1,929,268',
#   'Population estimates, July 1, 2017,  (V2017)': '1,920,076',
#   'Population estimates base, April 1, 2010,  (V2018)': '1,826,305',
#   'Population estimates base, April 1, 2010,  (V2017)': '1,826,327',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '5.6%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '5.1%',
# ...
#   'Population per square mile, 2010': '594.8',
#   'Land area in square miles, 2010': '9,707.24',
#   'FIPS Code': '24',
#   'State': 'MD',
#   'StateID': '24'},
#  {'Population estimates, July 1, 2018,  (V2018)': '6,902,149',
#   'Population estimates, July 1, 2017,  (V2017)': '6,859,819',
#   'Population estimates base, April 1, 2010,  (V2018)': '6,547,790',
#   'Population estimates base, April 1, 2010,  (V2017)': '6,547,808',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '5.4%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '4.8%',
#   'Population, Census, April 1, 2010': '6,547,629',
#   'Persons under 5 years, percent': '5.3%',
#   'Persons under 18 years, percent': '20.0%',
#   'Persons 65 years and over, percent': '16.2%',
#   'Female persons, percent': '51.5%',
#   'White alone, percent': '81.3%',
#   'Black or African American alone, percent(a)': '8.8%',
#   'American Indian and Alaska Native alone, percent(a)': '0.5%',
#   'Asian alone, percent(a)': '6.9%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.4%',
#   'Hispanic or Latino, percent(b)': '11.9%',
#   'White alone, not Hispanic or Latino, percent': '72.2%',
#   'Veterans, 2013-2017': '325,299',
#   'Foreign born persons, percent, 2013-2017': '16.2%',
#   'Housing units,  July 1, 2017,  (V2017)': '2,894,484',
#   'Owner-occupied housing unit rate, 2013-2017': '62.4%',
#   'Median value of owner-occupied housing units, 2013-2017': '$352,600',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$2,102',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$754',
#   'Median gross rent, 2013-2017': '$1,173',
#   'Building permits, 2017': '17,728',
#   'Households, 2013-2017': '2,585,715',
#   'Persons per household, 2013-2017': '2.53',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '87.0%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '23.1%',
#   'Households with a computer, percent, 2013-2017': '88.9%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '83.0%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '90.3%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '42.1%',
#   'With a disability, under age 65 years, percent, 2013-2017': '7.9%',
#   'Persons  without health insurance, under age 65 years, percent': '3.3%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '67.3%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '63.4%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '17,508,975',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '63,583,090',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '81,927,799',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '123,904,370',
#   'Total retail sales, 2012 ($1,000)(c)': '92,915,380',
#   'Total retail sales per capita, 2012(c)': '$13,980',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '29.3',
#   'Median household income (in 2017 dollars), 2013-2017': '$74,167',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$39,913',
#   'Persons in poverty, percent': '10.5%',
#   'Total employer establishments, 2016': '177,6311',
#   'Total employment, 2016': '3,254,7811',
#   'Total annual payroll, 2016 ($1,000)': '204,747,2001',
#   'Total employment, percent change, 2015-2016': '2.8%1',
#   'Total nonemployer establishments, 2016': '529,496',
#   'All firms, 2012': '607,664',
#   'Men-owned firms, 2012': '357,158',
#   'Women-owned firms, 2012': '199,210',
#   'Minority-owned firms, 2012': '89,967',
#   'Nonminority-owned firms, 2012': '499,959',
#   'Veteran-owned firms, 2012': '58,339',
#   'Nonveteran-owned firms, 2012': '525,667',
#   'Population per square mile, 2010': '839.4',
#   'Land area in square miles, 2010': '7,800.06',
#   'FIPS Code': '25',
#   'State': 'MA',
#   'StateID': '25'},
#  {'Population estimates, July 1, 2018,  (V2018)': '967,171',
#   'Population estimates, July 1, 2017,  (V2017)': '961,939',
#   'Population estimates base, April 1, 2010,  (V2018)': '897,934',
#   'Population estimates base, April 1, 2010,  (V2017)': '897,936',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '7.7%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '7.1%',
#   'Population, Census, April 1, 2010': '897,934',
#   'Persons under 5 years, percent': '5.7%',
#   'Persons under 18 years, percent': '21.3%',
#   'Persons 65 years and over, percent': '18.1%',
#   'Female persons, percent': '51.6%',
#   'White alone, percent': '69.7%',
#   'Black or African American alone, percent(a)': '22.8%',
#   'American Indian and Alaska Native alone, percent(a)': '0.6%',
#   'Asian alone, percent(a)': '4.1%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.6%',
#   'Hispanic or Latino, percent(b)': '9.3%',
#   'White alone, not Hispanic or Latino, percent': '62.3%',
#   'Veterans, 2013-2017': '66,854',
#   'Foreign born persons, percent, 2013-2017': '9.1%',
#   'Housing units,  July 1, 2017,  (V2017)': '432,872',
#   'Owner-occupied housing unit rate, 2013-2017': '71.3%',
#   'Median value of owner-occupied housing units, 2013-2017': '$238,600',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,533',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$450',
#   'Median gross rent, 2013-2017': '$1,076',
#   'Building permits, 2017': '6,601',
#   'Households, 2013-2017': '352,357',
#   'Persons per household, 2013-2017': '2.61',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '86.9%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '12.8%',
#   'Households with a computer, percent, 2013-2017': '88.4%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '79.6%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '89.3%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '31.0%',
#   'With a disability, under age 65 years, percent, 2013-2017': '8.2%',
#   'Persons  without health insurance, under age 65 years, percent': '6.4%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '61.9%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '58.3%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '2,148,437',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '7,003,251',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '22,597,384',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '5,628,914',
#   'Total retail sales, 2012 ($1,000)(c)': '14,456,001',
#   'Total retail sales per capita, 2012(c)': '$15,763',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '25.7',
#   'Median household income (in 2017 dollars), 2013-2017': '$63,036',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$32,625',
#   'Persons in poverty, percent': '13.6%',
#   'Total employer establishments, 2016': '25,3661',
#   'Total employment, 2016': '400,0691',
#   'Total annual payroll, 2016 ($1,000)': '21,196,3711',
#   'Total employment, percent change, 2015-2016': '0.7%1',
#   'Total nonemployer establishments, 2016': '63,121',
#   'All firms, 2012': '73,418',
#   'Men-owned firms, 2012': '38,328',
#   'Women-owned firms, 2012': '23,964',
#   'Minority-owned firms, 2012': '14,440',
#   'Nonminority-owned firms, 2012': '54,782',
#   'Veteran-owned firms, 2012': '7,206',
#   'Nonveteran-owned firms, 2012': '60,318',
#   'Population per square mile, 2010': '460.8',
#   'Land area in square miles, 2010': '1,948.54',
#   'FIPS Code': '10',
#   'State': 'DE',
#   'StateID': '10'},
#  {'Population estimates, July 1, 2018,  (V2018)': '702,455',
#   'Population estimates, July 1, 2017,  (V2017)': '693,972',
#   'Population estimates base, April 1, 2010,  (V2018)': '601,766',
#   'Population estimates base, April 1, 2010,  (V2017)': '601,766',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '16.7%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '15.3%',
#   'Population, Census, April 1, 2010': '601,723',
#   'Persons under 5 years, percent': '6.5%',
#   'Persons under 18 years, percent': '17.9%',
#   'Persons 65 years and over, percent': '12.1%',
#   'Female persons, percent': '52.6%',
#   'White alone, percent': '45.1%',
#   'Black or African American alone, percent(a)': '47.1%',
#   'American Indian and Alaska Native alone, percent(a)': '0.6%',
#   'Asian alone, percent(a)': '4.3%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.1%',
#   'Two or More Races, percent': '2.7%',
#   'Hispanic or Latino, percent(b)': '11.0%',
#   'White alone, not Hispanic or Latino, percent': '36.8%',
#   'Veterans, 2013-2017': '27,695',
#   'Foreign born persons, percent, 2013-2017': '14.0%',
#   'Housing units,  July 1, 2017,  (V2017)': '314,805',
#   'Owner-occupied housing unit rate, 2013-2017': '41.7%',
#   'Median value of owner-occupied housing units, 2013-2017': '$537,400',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$2,375',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$666',
#   'Median gross rent, 2013-2017': '$1,424',
#   'Building permits, 2017': '6,037',
#   'Households, 2013-2017': '277,985',
#   'Persons per household, 2013-2017': '2.28',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '80.0%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '17.5%',
#   'Households with a computer, percent, 2013-2017': '88.2%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '77.6%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '90.3%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '56.6%',
#   'With a disability, under age 65 years, percent, 2013-2017': '8.6%',
#   'Persons  without health insurance, under age 65 years, percent': '4.2%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '68.9%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '66.9%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '5,101,602',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '8,963,981',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '309,832',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '2,591,868',
#   'Total retail sales, 2012 ($1,000)(c)': '4,439,933',
#   'Total retail sales per capita, 2012(c)': '$7,022',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '30.0',
#   'Median household income (in 2017 dollars), 2013-2017': '$77,649',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$50,832',
#   'Persons in poverty, percent': '16.6%',
#   'Total employer establishments, 2016': '23,177',
#   'Total employment, 2016': '526,879',
#   'Total annual payroll, 2016 ($1,000)': '39,833,690',
#   'Total employment, percent change, 2015-2016': '2.7%',
#   'Total nonemployer establishments, 2016': '59,398',
#   'All firms, 2012': '63,408',
#   'Men-owned firms, 2012': '30,237',
#   'Women-owned firms, 2012': '27,064',
#   'Minority-owned firms, 2012': '29,983',
#   'Nonminority-owned firms, 2012': '29,521',
#   'Veteran-owned firms, 2012': '5,070',
#   'Nonveteran-owned firms, 2012': '54,217',
#   'Population per square mile, 2010': '9,856.5',
#   'Land area in square miles, 2010': '61.05',
#   'FIPS Code': '11',
#   'State': 'DC',
#   'StateID': '11'},
#  {'Population estimates, July 1, 2018,  (V2018)': '327,167,434',
#   'Population estimates, July 1, 2017,  (V2017)': '325,719,178',
#   'Population estimates base, April 1, 2010,  (V2018)': '308,758,105',
#   'Population estimates base, April 1, 2010,  (V2017)': '308,758,105',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2018,  (V2018)': '6.0%',
#   'Population, percent change - April 1, 2010 (estimates base) to July 1, 2017,  (V2017)': '5.5%',
#   'Population, Census, April 1, 2010': '308,745,538',
#   'Persons under 5 years, percent': '6.1%',
#   'Persons under 18 years, percent': '22.6%',
#   'Persons 65 years and over, percent': '15.6%',
#   'Female persons, percent': '50.8%',
#   'White alone, percent': '76.6%',
#   'Black or African American alone, percent(a)': '13.4%',
#   'American Indian and Alaska Native alone, percent(a)': '1.3%',
#   'Asian alone, percent(a)': '5.8%',
#   'Native Hawaiian and Other Pacific Islander alone, percent(a)': '0.2%',
#   'Two or More Races, percent': '2.7%',
#   'Hispanic or Latino, percent(b)': '18.1%',
#   'White alone, not Hispanic or Latino, percent': '60.7%',
#   'Veterans, 2013-2017': '18,939,219',
#   'Foreign born persons, percent, 2013-2017': '13.4%',
#   'Housing units,  July 1, 2017,  (V2017)': '137,403,460',
#   'Owner-occupied housing unit rate, 2013-2017': '63.8%',
#   'Median value of owner-occupied housing units, 2013-2017': '$193,500',
#   'Median selected monthly owner costs -with a mortgage, 2013-2017': '$1,515',
#   'Median selected monthly owner costs -without a mortgage, 2013-2017': '$474',
#   'Median gross rent, 2013-2017': '$982',
#   'Building permits, 2017': '1,281,977',
#   'Households, 2013-2017': '118,825,921',
#   'Persons per household, 2013-2017': '2.63',
#   'Living in same house 1 year ago, percent of persons age 1 year+, 2013-2017': '85.4%',
#   'Language other than English spoken at home, percent of persons age 5 years+, 2013-2017': '21.3%',
#   'Households with a computer, percent, 2013-2017': '87.2%',
#   'Households with a broadband Internet subscription, percent, 2013-2017': '78.1%',
#   'High school graduate or higher, percent of persons age 25 years+, 2013-2017': '87.3%',
#   "Bachelor's degree or higher, percent of persons age 25 years+, 2013-2017": '30.9%',
#   'With a disability, under age 65 years, percent, 2013-2017': '8.7%',
#   'Persons  without health insurance, under age 65 years, percent': '10.2%',
#   'In civilian labor force, total, percent of population age 16 years+, 2013-2017': '63.0%',
#   'In civilian labor force, female, percent of population age 16 years+, 2013-2017': '58.2%',
#   'Total accommodation and food services sales, 2012 ($1,000)(c)': '708,138,598',
#   'Total health care and social assistance receipts/revenue, 2012 ($1,000)(c)': '2,040,441,203',
#   'Total manufacturers shipments, 2012 ($1,000)(c)': '5,696,729,632',
#   'Total merchant wholesaler sales, 2012 ($1,000)(c)': '5,208,023,478',
#   'Total retail sales, 2012 ($1,000)(c)': '4,219,821,871',
#   'Total retail sales per capita, 2012(c)': '$13,443',
#   'Mean travel time to work (minutes), workers age 16 years+, 2013-2017': '26.4',
#   'Median household income (in 2017 dollars), 2013-2017': '$57,652',
#   'Per capita income in past 12 months (in 2017 dollars), 2013-2017': '$31,177',
#   'Persons in poverty, percent': '12.3%',
#   'Total employer establishments, 2016': '7,757,807',
#   'Total employment, 2016': '126,752,238',
#   'Total annual payroll, 2016 ($1,000)': '6,435,142,055',
#   'Total employment, percent change, 2015-2016': '2.1%',
#   'Total nonemployer establishments, 2016': '24,813,048',
#   'All firms, 2012': '27,626,360',
#   'Men-owned firms, 2012': '14,844,597',
#   'Women-owned firms, 2012': '9,878,397',
#   'Minority-owned firms, 2012': '7,952,386',
#   'Nonminority-owned firms, 2012': '18,987,918',
#   'Veteran-owned firms, 2012': '2,521,682',
#   'Nonveteran-owned firms, 2012': '24,070,685',
#   'Population per square mile, 2010': '87.4',
#   'Land area in square miles, 2010': '3,531,905.43',
#   'FIPS Code': '00',
#   'State': 'US',
#   'StateID': '100'}]

# %%
# Creates a collection in the database and inserts documents
db.veilofignorance.insert_many(records)
